# %%
using PyPlot
# Out:
# INFO: Loading help data...

# %%
1+1
# Out:
# 2

# %%
plot(1:4)
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11e0fb3d0>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x11e1dd350>
